# %% [markdown]
# # 📊 Statistical Toolbox
#
# Welcome to your comprehensive Statistical Toolbox! This notebook includes explanations, code, visualizations, and datasets for various statistical techniques.
#
# ---

# %% [markdown]
# ## 1. Descriptive Statistics
#
# **Tools:** Mean, Median, Mode, Variance, Std Dev, Histograms, Boxplots
#
# **Example Use Case:** Analyzing student exam scores

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset
scores = pd.DataFrame({"Exam Scores": np.random.normal(75, 10, 100)})

# Descriptive stats
print(scores.describe())

# Visualizations
sns.histplot(scores["Exam Scores"], kde=True)
plt.title("Distribution of Exam Scores")
plt.show()

# %% [markdown]
# ## 2. Probability Distributions
#
# **Tools:** Normal, Binomial, Poisson Distributions
#
# **Example Use Case:** Modeling service center wait times

# %%
from scipy.stats import norm, binom, poisson

# Normal distribution plot
x = np.linspace(50, 100, 500)
plt.plot(x, norm.pdf(x, 75, 10), label="Normal (μ=75, σ=10)")
plt.title("Normal Distribution")
plt.legend()
plt.show()

# %% [markdown]
# _Continue adding sections: Sampling, Hypothesis Testing, Regression, ANOVA, Time Series, etc._
